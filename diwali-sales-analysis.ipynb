# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns # seaborn is a data visulisation tool

# %%
import os
os.getcwd()

# %%
data = pd.read_csv('/kaggle/input/diwali-sale/Dsales.csv',  encoding= 'unicode_escape')

# %%
data.head()

# %%
data.shape

# %%
data.info()

# %%
#drop command use to drop any row nammed
data.drop(['Status', 'unnamed1'], axis =1, inplace = True)

# %%
# here what we see after using drop command 2 rows are deleted
data.info()

# %%
# Is not useful to use because it's outcome is true and false which is very hard to observe
#so, use the code below this syntax
pd.isnull(data)

# %%
pd.isnull(data).sum()

# %%
data.shape

# %%
# here inplace use to save the outcome if are not using that then it doesn't save the file 
# Drop null values
data.dropna(inplace = True)

# %%
data.shape

# %%
pd.isnull(data).sum()

# %%
# Change Data type
data['Amount'] = data['Amount'].astype('int')

# %%
# here what we see amount data type changed to int64 from float
data.info()

# %%
data['Amount'].dtypes

# %%
data.columns

# %%
# Rename column
data.rename (columns = {'Marital_Status' : 'Status'})

# %%
data.describe()

# %%
data[['Age', 'Orders', 'Amount']].describe()

# %% [markdown]
# #      Exploratory Data Analysis (EDA)
#
# **Gender**

# %%
data.columns

# %%
ax = sns.countplot(x = 'Gender', data = data)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
data.groupby(['Gender'], as_index = False)['Amount'].sum().sort_values(by = 'Amount', ascending = False)

# %%
Sales_gen = data.groupby(['Gender'], as_index = False)['Amount'].sum().sort_values(by = 'Amount', ascending = False)
sns.barplot(x = 'Gender', y = 'Amount', data = Sales_gen)

# %% [markdown]
# **From Above Graphs We Can See That Most of the buyers are Females and Even Purchasing Power of Females are Greater Than Man**

# %%
data.columns

# %%
ax = sns.countplot(x = 'Age Group', data = data, hue = 'Gender' )

for bars in ax.containers:
    ax.bar_label(bars)

# %%
Sales_age = data.groupby(['Age Group'], as_index = False)['Amount'].sum().sort_values(by = 'Amount', ascending = False)
sns.barplot(x = 'Age Group', y = 'Amount', data = Sales_age)

# %% [markdown]
# **** From Above graph we can see that most of the buyers are of age group 26-35 years Female ****

# %%
# Total numbers of orders from top 10 states
Sales_state = data.groupby(['State'], as_index = False)['Orders'].sum().sort_values(by = 'Orders', ascending = False).head(10)

sns.set(rc = {'figure.figsize':(20,6)})
sns.barplot(x = 'State', y = 'Orders', data = Sales_state)

# %%
Sales_state = data.groupby(['State'], as_index = False)['Amount'].sum().sort_values(by = 'Amount', ascending = False).head(10)

sns.set(rc = {'figure.figsize':(20,6)})
sns.barplot(x = 'State', y = 'Amount', data = Sales_state)

# %% [markdown]
# **** from above graph we understand that most of the orders an revenue from UP, MH, Karnataka ****

# %%
ax = sns.countplot(x = 'Marital_Status', data = data)

sns.set(rc = {'figure.figsize':(7,3)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
Sales_status = data.groupby(['Marital_Status', 'Gender'], as_index = False)['Amount'].sum().sort_values(by = 'Amount', ascending = False)

sns.set(rc = {'figure.figsize':(7,3)})
sns.barplot(x = 'Marital_Status', y = 'Amount', data = Sales_status, hue = 'Gender')

# %% [markdown]
# **Most of the purchaser are married woman and they have high purchasing power**

# %%
ax = sns.countplot(x = 'Occupation', data = data)

sns.set(rc = {'figure.figsize':(25,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
Sales_Occupation = data.groupby(['Occupation'], as_index = False)['Amount'].sum().sort_values(by = 'Amount', ascending = False)

sns.set(rc = {'figure.figsize':(20,6)})
sns.barplot(x = 'Occupation', y = 'Amount', data = Sales_Occupation)

# %% [markdown]
# **From above data most of buyers belon to IT Sector
# **

# %%
ax = sns.countplot(x = 'Product_Category', data = data)

sns.set(rc = {'figure.figsize':(20,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
Sales_Category = data.groupby(['Product_Category'], as_index = False)['Amount'].sum().sort_values(by = 'Amount', ascending = False).head(10)

sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(x = 'Product_Category', y = 'Amount', data = Sales_Category)

# %% [markdown]
# **** From Above we conclude that most of the sold products are food, clothing and electronics****

# %%
Sales_Category = data.groupby(['Product_ID'], as_index = False)['Orders'].sum().sort_values(by = 'Orders', ascending = False).head(10)

sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(x = 'Product_ID', y = 'Orders', data = Sales_Category)

# %%
# top 10 most sold products (same thing as above)

fig1,ax1 = plt.subplots(figsize = (12,7))
data.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending = False).plot(kind = 'bar')

# %% [markdown]
# # **Conclusion** #
#
# **Married woman age group from UP, MH and Karnataka working in IT, Healthcare and Aviation are more likely buy products from Food, Clohing and Electronics Category**
